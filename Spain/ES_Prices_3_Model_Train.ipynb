# %%
import Model_train as train
import time

# %%
start = time.time()

crop = 'BLUEBERRIES'
ctry = 'ES'
trade_ctry = 'EU'
train.train_sarimax_model(crop, ctry, trade_ctry)

end = time.time()
duration = end - start
minutes = duration // 60
seconds = duration - (minutes * 60)
print(f"{minutes} minutes and {seconds} seconds")
# Out:
# Best ARIMANone MAE=inf
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-8-f2832ef9c1e8> in <module>
#       4 ctry = 'ES'
#       5 trade_ctry = 'EU'
# ----> 6 train.train_sarimax_model(crop, ctry, trade_ctry)
#       7
#       8 end = time.time()
#
# c:\Berries_Pricing\Spain\Model_train.py in train_sarimax_model(crop, ctry, trade_ctry)
#     208
#     209     # Generate model!
# --> 210     model = SARIMAX(df_prices_all_train, exog = exog_train, order = best_model, seasonal_order=(1, 1, 1, 52)).fit()
#     211
#     212     # SAVE MODEL
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     652                 flags['hessian_method'] = optim_hessian
#     653             fargs = (flags,)
# --> 654             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     655                                                fargs=fargs,
#     656                                                maxiter=maxiter,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     516         warn_convergence = kwargs.pop('warn_convergence', True)
#     517         optimizer = Optimizer()
# --> 518         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     519                                                        fargs, kwargs,
#     520                                                        hessian=hess,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     213
#     214         func = fit_funcs[method]
# --> 215         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     216                             disp=disp, maxiter=maxiter, callback=callback,
#     217                             retall=retall, full_output=full_output,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     435         func = f
#     436
# --> 437     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     438                                      callback=callback, args=fargs,
#     439                                      bounds=bounds, disp=disp,
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     196             'maxls': maxls}
#     197
# --> 198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     199                            **opts)
#     200     d = {'grad': res['jac'],
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\scipy\optimize\lbfgsb.py in func_and_grad(x)
#     288     if jac is None:
#     289         def func_and_grad(x):
# --> 290             f = fun(x, *args)
#     291             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     292             return f, g
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\base\model.py in f(params, *args)
#     498
#     499         def f(params, *args):
# --> 500             return -self.loglike(params, *args) / nobs
#     501
#     502         if method == 'newton':
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in loglike(self, params, *args, **kwargs)
#     887             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     888
# --> 889         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     890
#     891         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in loglike(self, **kwargs)
#     975         kwargs.setdefault('conserve_memory',
#     976                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 977         kfilter = self._filter(**kwargs)
#     978         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     979                                         self.loglikelihood_burn)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     895
#     896         # Initialize the state
# --> 897         self._initialize_state(prefix=prefix, complex_step=complex_step)
#     898
#     899         # Run the filter
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\tsa\statespace\representation.py in _initialize_state(self, prefix, complex_step)
#     947             if not self.initialization.initialized:
#     948                 raise RuntimeError('Initialization is incomplete.')
# --> 949             self._statespaces[prefix].initialize(self.initialization,
#     950                                                  complex_step=complex_step)
#     951         else:
#
# statsmodels\tsa\statespace\_representation.pyx in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# statsmodels\tsa\statespace\_representation.pyx in statsmodels.tsa.statespace._representation.dStatespace.initialize()
#
# statsmodels\tsa\statespace\_initialization.pyx in statsmodels.tsa.statespace._initialization.dInitialization.initialize()
#
# statsmodels\tsa\statespace\_initialization.pyx in statsmodels.tsa.statespace._initialization.dInitialization.initialize_stationary_stationary_cov()
#
# statsmodels\tsa\statespace\_tools.pyx in statsmodels.tsa.statespace._tools._dsolve_discrete_lyapunov()
#
# LinAlgError: Schur decomposition solver error.

# %%
start = time.time()

crop = 'RASPBERRIES'
ctry = 'ES'
train.train_arima_model(crop, ctry)

end = time.time()
duration = end - start
minutes = duration // 60
seconds = duration - (minutes * 60)
print(f"{minutes} minutes and {seconds} seconds")
# Out:
# ARIMA(0, 0, 0) MAE=5.455
# ARIMA(0, 0, 1) MAE=2.803
# ARIMA(0, 0, 2) MAE=1.683
# ARIMA(0, 0, 3) MAE=1.120
# ARIMA(0, 0, 4) MAE=1.108
# ARIMA(0, 1, 0) MAE=0.411
# ARIMA(0, 1, 1) MAE=0.407
# ARIMA(0, 1, 2) MAE=0.411
# ARIMA(0, 1, 3) MAE=0.421
# ARIMA(0, 1, 4) MAE=0.420
# ARIMA(0, 2, 0) MAE=0.558
# ARIMA(0, 2, 1) MAE=0.414
# ARIMA(0, 2, 2) MAE=0.411
# ARIMA(0, 2, 3) MAE=0.416
# ARIMA(0, 2, 4) MAE=0.424
# ARIMA(0, 3, 0) MAE=0.883
# ARIMA(0, 3, 1) MAE=0.560
# ARIMA(0, 3, 2) MAE=0.418
# ARIMA(0, 3, 3) MAE=0.418
# ARIMA(0, 3, 4) MAE=0.426
# ARIMA(0, 4, 0) MAE=1.545
# ARIMA(0, 4, 1) MAE=0.886
# ARIMA(0, 4, 2) MAE=0.567
# ARIMA(0, 4, 3) MAE=0.436
# ARIMA(0, 4, 4) MAE=0.428
# ARIMA(1, 0, 0) MAE=0.412
# ARIMA(1, 0, 1) MAE=0.409
# ARIMA(1, 0, 2) MAE=0.415
# ARIMA(1, 0, 3) MAE=0.424
# ARIMA(1, 0, 4) MAE=0.424
# ARIMA(1, 1, 0) MAE=0.410
# ARIMA(1, 1, 1) MAE=0.408
# ARIMA(1, 1, 2) MAE=0.384
# ARIMA(1, 1, 3) MAE=0.389
# ARIMA(1, 1, 4) MAE=0.384
# ARIMA(1, 2, 0) MAE=0.547
# ARIMA(1, 2, 1) MAE=0.413
# ARIMA(1, 2, 2) MAE=0.412
# ARIMA(1, 2, 3) MAE=0.412
# ARIMA(1, 2, 4) MAE=0.411
# ARIMA(1, 3, 0) MAE=0.805
# ARIMA(1, 3, 1) MAE=0.548
# ARIMA(1, 3, 2) MAE=0.421
# ARIMA(1, 3, 3) MAE=0.420
# ARIMA(1, 3, 4) MAE=0.421
# ARIMA(1, 4, 0) MAE=1.284
# ARIMA(1, 4, 1) MAE=0.807
# ARIMA(1, 4, 2) MAE=0.552
# ARIMA(1, 4, 3) MAE=0.476
# ARIMA(1, 4, 4) MAE=0.425
# ARIMA(2, 0, 0) MAE=0.411
# ARIMA(2, 0, 1) MAE=0.411
# ARIMA(2, 0, 2) MAE=0.414
# ARIMA(2, 0, 3) MAE=0.414
# ARIMA(2, 0, 4) MAE=0.412
# ARIMA(2, 1, 0) MAE=0.410
# ARIMA(2, 1, 1) MAE=0.411
# ARIMA(2, 1, 2) MAE=0.381
# ARIMA(2, 1, 4) MAE=0.392
# ARIMA(2, 2, 0) MAE=0.480
# ARIMA(2, 2, 1) MAE=0.412
# ARIMA(2, 2, 2) MAE=0.413
# ARIMA(2, 2, 3) MAE=0.423
# ARIMA(2, 2, 4) MAE=0.411
# ARIMA(2, 3, 0) MAE=0.637
# ARIMA(2, 3, 1) MAE=0.483
# ARIMA(2, 3, 2) MAE=0.439
# ARIMA(2, 3, 3) MAE=0.421
# ARIMA(2, 3, 4) MAE=0.452
# ARIMA(2, 4, 0) MAE=0.966
# ARIMA(2, 4, 1) MAE=0.640
# ARIMA(2, 4, 2) MAE=0.489
# ARIMA(2, 4, 3) MAE=0.553
# ARIMA(2, 4, 4) MAE=0.456
# ARIMA(3, 0, 0) MAE=0.413
# ARIMA(3, 0, 1) MAE=0.413
# ARIMA(3, 0, 3) MAE=0.422
# ARIMA(3, 0, 4) MAE=0.405
# ARIMA(3, 1, 0) MAE=0.419
# ARIMA(3, 1, 1) MAE=0.401
# ARIMA(3, 1, 2) MAE=0.379
# ARIMA(3, 1, 3) MAE=0.387
# ARIMA(3, 1, 4) MAE=0.400
# ARIMA(3, 2, 0) MAE=0.475
# ARIMA(3, 2, 1) MAE=0.423
# ARIMA(3, 2, 2) MAE=0.416
# ARIMA(3, 2, 3) MAE=0.417
# ARIMA(3, 2, 4) MAE=0.419
# ARIMA(3, 3, 0) MAE=0.591
# ARIMA(3, 3, 1) MAE=0.478
# ARIMA(3, 3, 2) MAE=0.474
# ARIMA(3, 3, 3) MAE=0.431
# ARIMA(3, 3, 4) MAE=0.442
# ARIMA(3, 4, 0) MAE=0.810
# ARIMA(3, 4, 1) MAE=0.593
# ARIMA(3, 4, 2) MAE=0.490
# ARIMA(3, 4, 3) MAE=0.489
# ARIMA(3, 4, 4) MAE=0.566
# ARIMA(4, 0, 0) MAE=0.422
# ARIMA(4, 0, 1) MAE=0.401
# ARIMA(4, 0, 2) MAE=0.426
# ARIMA(4, 0, 3) MAE=0.426
# ARIMA(4, 0, 4) MAE=0.422
# ARIMA(4, 1, 0) MAE=0.414
# ARIMA(4, 1, 1) MAE=0.376
# ARIMA(4, 1, 2) MAE=0.384
# ARIMA(4, 1, 3) MAE=0.387
# ARIMA(4, 1, 4) MAE=0.386
# ARIMA(4, 2, 0) MAE=0.486
# ARIMA(4, 2, 1) MAE=0.419
# ARIMA(4, 2, 2) MAE=0.422
# ARIMA(4, 2, 3) MAE=0.425
# ARIMA(4, 2, 4) MAE=0.437
# ARIMA(4, 3, 0) MAE=0.603
# ARIMA(4, 3, 1) MAE=0.488
# ARIMA(4, 3, 2) MAE=0.466
# ARIMA(4, 3, 4) MAE=0.434
# ARIMA(4, 4, 0) MAE=0.742
# ARIMA(4, 4, 1) MAE=0.606
# ARIMA(4, 4, 2) MAE=0.509
# ARIMA(4, 4, 3) MAE=0.485
# ARIMA(4, 4, 4) MAE=0.501
# ARIMA(5, 0, 0) MAE=0.419
# ARIMA(5, 0, 1) MAE=0.421
# ARIMA(5, 0, 2) MAE=0.406
# ARIMA(5, 0, 3) MAE=0.429
# ARIMA(5, 0, 4) MAE=0.419
# ARIMA(5, 1, 0) MAE=0.406
# ARIMA(5, 1, 1) MAE=0.375
# ARIMA(5, 1, 2) MAE=0.379
# ARIMA(5, 1, 3) MAE=0.398
# ARIMA(5, 1, 4) MAE=0.392
# ARIMA(5, 2, 0) MAE=0.483
# ARIMA(5, 2, 1) MAE=0.411
# ARIMA(5, 2, 2) MAE=0.422
# ARIMA(5, 2, 3) MAE=0.442
# ARIMA(5, 2, 4) MAE=0.480
# ARIMA(5, 3, 0) MAE=0.586
# ARIMA(5, 3, 1) MAE=0.485
# ARIMA(5, 3, 2) MAE=0.491
# ARIMA(5, 3, 3) MAE=0.506
# ARIMA(5, 3, 4) MAE=0.440
# ARIMA(5, 4, 0) MAE=0.744
# ARIMA(5, 4, 1) MAE=0.589
# ARIMA(5, 4, 2) MAE=0.610
# ARIMA(5, 4, 4) MAE=0.499
# ARIMA(6, 0, 0) MAE=0.411
# ARIMA(6, 0, 1) MAE=0.392
# ARIMA(6, 0, 2) MAE=0.400
# ARIMA(6, 1, 0) MAE=0.408
# ARIMA(6, 1, 2) MAE=0.388
# ARIMA(6, 1, 3) MAE=0.385
# ARIMA(6, 1, 4) MAE=0.382
# ARIMA(6, 2, 0) MAE=0.472
# ARIMA(6, 2, 1) MAE=0.412
# ARIMA(6, 2, 2) MAE=0.409
# ARIMA(6, 2, 3) MAE=0.424
# ARIMA(6, 2, 4) MAE=0.437
# ARIMA(6, 3, 0) MAE=0.553
# ARIMA(6, 3, 1) MAE=0.473
# ARIMA(6, 3, 3) MAE=0.486
# ARIMA(6, 3, 4) MAE=0.463
# ARIMA(6, 4, 0) MAE=0.719
# ARIMA(6, 4, 1) MAE=0.557
# ARIMA(6, 4, 2) MAE=0.477
# ARIMA(6, 4, 3) MAE=0.568
# ARIMA(6, 4, 4) MAE=0.505
# ARIMA(7, 0, 0) MAE=0.410
# ARIMA(7, 0, 3) MAE=0.422
# ARIMA(7, 0, 4) MAE=0.420
# ARIMA(7, 1, 0) MAE=0.408
# ARIMA(7, 1, 1) MAE=0.409
# ARIMA(7, 1, 2) MAE=0.385
# ARIMA(7, 1, 3) MAE=0.394
# ARIMA(7, 1, 4) MAE=0.379
# ARIMA(7, 2, 0) MAE=0.474
# ARIMA(7, 2, 1) MAE=0.412
# ARIMA(7, 2, 3) MAE=0.419
# ARIMA(7, 3, 0) MAE=0.531
# ARIMA(7, 3, 1) MAE=0.476
# ARIMA(7, 3, 2) MAE=0.471
# ARIMA(7, 3, 3) MAE=0.461
# ARIMA(7, 3, 4) MAE=0.464
# ARIMA(7, 4, 0) MAE=0.635
# ARIMA(7, 4, 1) MAE=0.535
# ARIMA(7, 4, 2) MAE=0.508
# ARIMA(7, 4, 4) MAE=0.488
# ARIMA(8, 0, 0) MAE=0.409
# ARIMA(8, 0, 1) MAE=0.415
# ARIMA(8, 0, 3) MAE=0.416
# ARIMA(8, 0, 4) MAE=0.413
# ARIMA(8, 1, 0) MAE=0.398
# ARIMA(8, 1, 1) MAE=0.398
# ARIMA(8, 1, 2) MAE=0.400
# ARIMA(8, 1, 3) MAE=0.396
# ARIMA(8, 1, 4) MAE=0.406
# ARIMA(8, 2, 0) MAE=0.487
# ARIMA(8, 2, 1) MAE=0.400
# ARIMA(8, 2, 2) MAE=0.398
# ARIMA(8, 2, 3) MAE=0.419
# ARIMA(8, 2, 4) MAE=0.421
# ARIMA(8, 3, 0) MAE=0.548
# ARIMA(8, 3, 1) MAE=0.488
# ARIMA(8, 3, 2) MAE=0.446
# ARIMA(8, 3, 4) MAE=0.439
# ARIMA(8, 4, 0) MAE=0.635
# ARIMA(8, 4, 1) MAE=0.551
# ARIMA(8, 4, 2) MAE=0.523
# ARIMA(8, 4, 3) MAE=0.525
# ARIMA(8, 4, 4) MAE=0.499
# ARIMA(9, 0, 0) MAE=0.398
# ARIMA(9, 0, 1) MAE=0.398
# ARIMA(9, 0, 2) MAE=0.418
# ARIMA(9, 0, 4) MAE=0.407
# ARIMA(9, 1, 0) MAE=0.391
# ARIMA(9, 1, 1) MAE=0.400
# ARIMA(9, 1, 2) MAE=0.400
# ARIMA(9, 1, 3) MAE=0.414
# ARIMA(9, 1, 4) MAE=0.401
# ARIMA(9, 2, 0) MAE=0.468
# ARIMA(9, 2, 1) MAE=0.392
# ARIMA(9, 2, 2) MAE=0.397
# ARIMA(9, 2, 3) MAE=0.411
# ARIMA(9, 2, 4) MAE=0.415
# ARIMA(9, 3, 0) MAE=0.555
# ARIMA(9, 3, 1) MAE=0.471
# ARIMA(9, 3, 2) MAE=0.410
# ARIMA(9, 3, 3) MAE=0.448
# ARIMA(9, 3, 4) MAE=0.488
# ARIMA(9, 4, 0) MAE=0.663
# ARIMA(9, 4, 1) MAE=0.557
# ARIMA(9, 4, 4) MAE=0.477
# Best ARIMA(5, 1, 1) MAE=0.375
# 179.0 minutes and 57.14636540412903 seconds

# %%
start = time.time()

crop = 'STRAWBERRIES'
ctry = 'ES'
train.train_arima_model(crop, ctry)

end = time.time()
duration = end - start
minutes = duration // 60
seconds = duration - (minutes * 60)
print(f"{minutes} minutes and {seconds} seconds")
# Out:
# ARIMA(0, 0, 0) MAE=1.550
# ARIMA(0, 0, 1) MAE=0.869
# ARIMA(0, 0, 2) MAE=0.678
# ARIMA(0, 0, 3) MAE=0.507
# ARIMA(0, 0, 4) MAE=0.455
# ARIMA(0, 1, 0) MAE=0.270
# ARIMA(0, 1, 1) MAE=0.280
# ARIMA(0, 1, 2) MAE=0.304
# ARIMA(0, 1, 3) MAE=0.311
# ARIMA(0, 1, 4) MAE=0.315
# ARIMA(0, 2, 0) MAE=0.417
# ARIMA(0, 2, 1) MAE=0.275
# ARIMA(0, 2, 2) MAE=0.286
# ARIMA(0, 2, 3) MAE=0.302
# ARIMA(0, 2, 4) MAE=0.307
# ARIMA(0, 3, 0) MAE=0.785
# ARIMA(0, 3, 1) MAE=0.420
# ARIMA(0, 3, 2) MAE=0.306
# ARIMA(0, 3, 3) MAE=0.350
# ARIMA(0, 3, 4) MAE=0.329
# ARIMA(0, 4, 0) MAE=1.529
# ARIMA(0, 4, 1) MAE=0.790
# ARIMA(0, 4, 2) MAE=0.426
# ARIMA(0, 4, 3) MAE=0.388
# ARIMA(0, 4, 4) MAE=0.513
# ARIMA(1, 0, 0) MAE=0.258
# ARIMA(1, 0, 1) MAE=0.271
# ARIMA(1, 0, 2) MAE=0.279
# ARIMA(1, 0, 3) MAE=0.289
# ARIMA(1, 0, 4) MAE=0.293
# ARIMA(1, 1, 0) MAE=0.276
# ARIMA(1, 1, 1) MAE=0.296
# ARIMA(1, 1, 2) MAE=0.374
# ARIMA(1, 1, 3) MAE=0.350
# ARIMA(1, 1, 4) MAE=0.305
# ARIMA(1, 2, 0) MAE=0.420
# ARIMA(1, 2, 1) MAE=0.282
# ARIMA(1, 2, 2) MAE=0.323
# ARIMA(1, 2, 3) MAE=0.300
# ARIMA(1, 2, 4) MAE=0.302
# ARIMA(1, 3, 0) MAE=0.598
# ARIMA(1, 3, 1) MAE=0.423
# ARIMA(1, 3, 2) MAE=0.312
# ARIMA(1, 3, 3) MAE=0.328
# ARIMA(1, 3, 4) MAE=0.332
# ARIMA(1, 4, 0) MAE=1.003
# ARIMA(1, 4, 1) MAE=0.600
# ARIMA(1, 4, 2) MAE=0.432
# ARIMA(1, 4, 3) MAE=0.368
# ARIMA(1, 4, 4) MAE=0.409
# ARIMA(2, 0, 0) MAE=0.268
# ARIMA(2, 0, 1) MAE=0.274
# ARIMA(2, 0, 2) MAE=0.366
# ARIMA(2, 0, 3) MAE=0.299
# ARIMA(2, 0, 4) MAE=0.311
# ARIMA(2, 1, 0) MAE=0.306
# ARIMA(2, 1, 1) MAE=0.375
# ARIMA(2, 1, 2) MAE=0.307
# ARIMA(2, 1, 3) MAE=0.350
# ARIMA(2, 1, 4) MAE=0.310
# ARIMA(2, 2, 0) MAE=0.431
# ARIMA(2, 2, 1) MAE=0.306
# ARIMA(2, 2, 2) MAE=0.306
# ARIMA(2, 2, 3) MAE=0.321
# ARIMA(2, 2, 4) MAE=0.316
# ARIMA(2, 3, 0) MAE=0.574
# ARIMA(2, 3, 1) MAE=0.434
# ARIMA(2, 3, 2) MAE=0.437
# ARIMA(2, 3, 3) MAE=0.330
# ARIMA(2, 3, 4) MAE=0.359
# ARIMA(2, 4, 0) MAE=0.827
# ARIMA(2, 4, 1) MAE=0.575
# ARIMA(2, 4, 2) MAE=0.445
# ARIMA(2, 4, 3) MAE=0.481
# ARIMA(2, 4, 4) MAE=0.474
# ARIMA(3, 0, 0) MAE=0.287
# ARIMA(3, 0, 1) MAE=0.343
# ARIMA(3, 0, 2) MAE=0.283
# ARIMA(3, 0, 3) MAE=0.295
# ARIMA(3, 0, 4) MAE=0.301
# ARIMA(3, 1, 0) MAE=0.303
# ARIMA(3, 1, 1) MAE=0.310
# ARIMA(3, 1, 2) MAE=0.317
# ARIMA(3, 1, 3) MAE=0.390
# ARIMA(3, 1, 4) MAE=0.356
# ARIMA(3, 2, 0) MAE=0.439
# ARIMA(3, 2, 1) MAE=0.302
# ARIMA(3, 2, 2) MAE=0.310
# ARIMA(3, 2, 3) MAE=0.320
# ARIMA(3, 2, 4) MAE=0.335
# ARIMA(3, 3, 0) MAE=0.552
# ARIMA(3, 3, 1) MAE=0.444
# ARIMA(3, 3, 2) MAE=0.337
# ARIMA(3, 3, 3) MAE=0.394
# ARIMA(3, 3, 4) MAE=0.353
# ARIMA(3, 4, 0) MAE=0.781
# ARIMA(3, 4, 1) MAE=0.554
# ARIMA(3, 4, 2) MAE=0.467
# ARIMA(3, 4, 3) MAE=0.573
# ARIMA(3, 4, 4) MAE=0.470
# ARIMA(4, 0, 0) MAE=0.281
# ARIMA(4, 0, 1) MAE=0.289
# ARIMA(4, 0, 2) MAE=0.294
# ARIMA(4, 0, 3) MAE=0.317
# ARIMA(4, 0, 4) MAE=0.310
# ARIMA(4, 1, 0) MAE=0.310
# ARIMA(4, 1, 1) MAE=0.348
# ARIMA(4, 1, 2) MAE=0.387
# ARIMA(4, 1, 3) MAE=0.368
# ARIMA(4, 1, 4) MAE=0.398
# ARIMA(4, 2, 0) MAE=0.412
# ARIMA(4, 2, 1) MAE=0.309
# ARIMA(4, 2, 2) MAE=0.344
# ARIMA(4, 2, 3) MAE=0.338
# ARIMA(4, 2, 4) MAE=0.317
# ARIMA(4, 3, 0) MAE=0.575
# ARIMA(4, 3, 1) MAE=0.416
# ARIMA(4, 3, 2) MAE=0.425
# ARIMA(4, 3, 3) MAE=0.417
# ARIMA(4, 3, 4) MAE=0.385
# ARIMA(4, 4, 0) MAE=0.735
# ARIMA(4, 4, 1) MAE=0.577
# ARIMA(4, 4, 3) MAE=0.518
# ARIMA(4, 4, 4) MAE=0.571
# ARIMA(5, 0, 0) MAE=0.286
# ARIMA(5, 0, 1) MAE=0.291
# ARIMA(5, 0, 2) MAE=0.294
# ARIMA(5, 0, 3) MAE=0.330
# ARIMA(5, 0, 4) MAE=0.347
# ARIMA(5, 1, 0) MAE=0.312
# ARIMA(5, 1, 1) MAE=0.345
# ARIMA(5, 1, 2) MAE=0.387
# ARIMA(5, 1, 3) MAE=0.399
# ARIMA(5, 1, 4) MAE=0.382
# ARIMA(5, 2, 0) MAE=0.401
# ARIMA(5, 2, 1) MAE=0.311
# ARIMA(5, 2, 2) MAE=0.315
# ARIMA(5, 2, 3) MAE=0.339
# ARIMA(5, 2, 4) MAE=0.346
# ARIMA(5, 3, 0) MAE=0.574
# ARIMA(5, 3, 1) MAE=0.406
# ARIMA(5, 3, 2) MAE=0.341
# ARIMA(5, 3, 3) MAE=0.455
# ARIMA(5, 3, 4) MAE=0.362
# ARIMA(5, 4, 0) MAE=0.730
# ARIMA(5, 4, 1) MAE=0.577
# ARIMA(5, 4, 3) MAE=0.583
# ARIMA(5, 4, 4) MAE=0.494
# ARIMA(6, 0, 0) MAE=0.292
# ARIMA(6, 0, 1) MAE=0.294
# ARIMA(6, 0, 2) MAE=0.292
# ARIMA(6, 0, 3) MAE=0.343
# ARIMA(6, 0, 4) MAE=0.363
# ARIMA(6, 1, 0) MAE=0.311
# ARIMA(6, 1, 1) MAE=0.307
# ARIMA(6, 1, 2) MAE=0.359
# ARIMA(6, 1, 3) MAE=0.368
# ARIMA(6, 1, 4) MAE=0.342
# ARIMA(6, 2, 0) MAE=0.394
# ARIMA(6, 2, 1) MAE=0.311
# ARIMA(6, 2, 4) MAE=0.340
# ARIMA(6, 3, 0) MAE=0.572
# ARIMA(6, 3, 1) MAE=0.399
# ARIMA(6, 3, 2) MAE=0.453
# ARIMA(6, 3, 3) MAE=0.462
# ARIMA(6, 3, 4) MAE=0.376
# ARIMA(6, 4, 0) MAE=0.701
# ARIMA(6, 4, 1) MAE=0.578
# ARIMA(6, 4, 2) MAE=0.638
# ARIMA(6, 4, 3) MAE=0.528
# ARIMA(6, 4, 4) MAE=0.474
# ARIMA(7, 0, 0) MAE=0.291
# ARIMA(7, 0, 1) MAE=0.297
# ARIMA(7, 0, 3) MAE=0.318
# ARIMA(7, 0, 4) MAE=0.354
# ARIMA(7, 1, 0) MAE=0.311
# ARIMA(7, 1, 1) MAE=0.311
# ARIMA(7, 1, 2) MAE=0.328
# ARIMA(7, 1, 3) MAE=0.368
# ARIMA(7, 1, 4) MAE=0.354
# ARIMA(7, 2, 0) MAE=0.379
# ARIMA(7, 2, 1) MAE=0.312
# ARIMA(7, 2, 2) MAE=0.307
# ARIMA(7, 2, 3) MAE=0.342
# ARIMA(7, 2, 4) MAE=0.347
# ARIMA(7, 3, 0) MAE=0.505
# ARIMA(7, 3, 1) MAE=0.382
# ARIMA(7, 3, 2) MAE=0.359
# ARIMA(7, 3, 3) MAE=0.453
# ARIMA(7, 3, 4) MAE=0.382
# ARIMA(7, 4, 0) MAE=0.689
# ARIMA(7, 4, 1) MAE=0.512
# ARIMA(7, 4, 2) MAE=0.423
# ARIMA(7, 4, 3) MAE=0.558
# ARIMA(7, 4, 4) MAE=0.444
# ARIMA(8, 0, 0) MAE=0.291
# ARIMA(8, 0, 1) MAE=0.285
# ARIMA(8, 0, 2) MAE=0.315
# ARIMA(8, 0, 3) MAE=0.344
# ARIMA(8, 0, 4) MAE=0.317
# ARIMA(8, 1, 0) MAE=0.311
# ARIMA(8, 1, 1) MAE=0.312
# ARIMA(8, 1, 2) MAE=0.330
# ARIMA(8, 1, 3) MAE=0.302
# ARIMA(8, 2, 0) MAE=0.392
# ARIMA(8, 2, 1) MAE=0.314
# ARIMA(8, 2, 2) MAE=0.315
# ARIMA(8, 2, 3) MAE=0.350
# ARIMA(8, 2, 4) MAE=0.382
# ARIMA(8, 3, 0) MAE=0.477
# ARIMA(8, 3, 1) MAE=0.394
# ARIMA(8, 3, 2) MAE=0.452
# ARIMA(8, 3, 3) MAE=0.371
# ARIMA(8, 3, 4) MAE=0.472
# ARIMA(8, 4, 0) MAE=0.659
# ARIMA(8, 4, 1) MAE=0.478
# ARIMA(8, 4, 2) MAE=0.433
# ARIMA(8, 4, 3) MAE=0.499
# ARIMA(8, 4, 4) MAE=0.650
# ARIMA(9, 0, 0) MAE=0.283
# ARIMA(9, 0, 1) MAE=0.284
# ARIMA(9, 0, 2) MAE=0.285
# ARIMA(9, 0, 3) MAE=0.316
# ARIMA(9, 1, 0) MAE=0.310
# ARIMA(9, 1, 1) MAE=0.360
# ARIMA(9, 1, 2) MAE=0.370
# ARIMA(9, 1, 3) MAE=0.378
# ARIMA(9, 1, 4) MAE=0.399
# ARIMA(9, 2, 0) MAE=0.406
# ARIMA(9, 2, 1) MAE=0.313
# ARIMA(9, 2, 2) MAE=0.357
# ARIMA(9, 2, 3) MAE=0.351
# ARIMA(9, 2, 4) MAE=0.377
# ARIMA(9, 3, 0) MAE=0.471
# ARIMA(9, 3, 1) MAE=0.404
# ARIMA(9, 3, 2) MAE=0.450
# ARIMA(9, 3, 3) MAE=0.439
# ARIMA(9, 3, 4) MAE=0.385
# ARIMA(9, 4, 0) MAE=0.632
# ARIMA(9, 4, 1) MAE=0.473
# ARIMA(9, 4, 2) MAE=0.440
# ARIMA(9, 4, 3) MAE=0.453
# ARIMA(9, 4, 4) MAE=0.482
# Best ARIMA(1, 0, 0) MAE=0.258
# 88.0 minutes and 49.977975606918335 seconds
